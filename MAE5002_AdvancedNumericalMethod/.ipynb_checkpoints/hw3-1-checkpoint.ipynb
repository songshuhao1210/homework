# %% [markdown]
# # Hw 3-1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### parameters

# %%
eps = 1e-12      # error treshold
xx = np.arange(-20,20,0.05)

# %% [markdown]
# ### plot the function in comparison with y = x

# %%
def func(x,flag_func):
    if flag_func == 1:
        return pow(x,5)-7*pow(x,3)-2*pow(x,2)+2
    elif flag_func == 2:
        return np.sin(np.cos(x))
    elif flag_func == 3:
        return pow(x,2)*np.sin(x+np.pi/3)
    else:
        return pow(x,2)+np.sin(x+np.pi/3)

# %%
def plot_com(xx,func_this,flag_func):
    plt.figure(figsize = (7,5))
    plt.plot(xx,xx)
    plt.plot(xx,func_this)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend(('y = x','y = g(x)'),fontsize=12, numpoints=1,loc=3)
    plt.savefig('comparison_flag_'+str(flag_func)+'.png',dpi=300)

# %%
for flag_func in range(1,5):
    func_this = np.zeros(np.size(xx))
    for x in xx:
        func_this[xx == x] = func(x,flag_func)
    plot_com(xx,func_this,flag_func)

# %% [markdown]
# ### Bisection method

# %%
flag_bis = 1; #0--do not proceeed; 1-- proceed

# %%
def bisection(flag_func,flag_bis,)
# Out:
#   Input In [218]
#     def bisection(flag_func,flag_bis,)
#                                       ^
# SyntaxError: invalid syntax
